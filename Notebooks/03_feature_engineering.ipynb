# %%
# ============================
# ⚙️ PHASE 3: FEATURE ENGINEERING
# ============================

import pandas as pd
import numpy as np

# ----------------------------
# Load cleaned data
# ----------------------------
data = pd.read_csv('../data/processed/stocks_clean.csv', parse_dates=['Date'])
data = data.sort_values('Date').reset_index(drop=True)
print("✅ Data loaded for feature engineering")
print("Shape:", data.shape)

# ----------------------------
# Create technical indicators for each stock
# ----------------------------
stocks = ['RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS']

for stock in stocks:
    close_col = f'Close_{stock}'
    
    # Daily return
    data[f'{stock}_Return'] = data[close_col].pct_change()

    # 7-day and 21-day moving averages
    data[f'{stock}_MA7'] = data[close_col].rolling(window=7).mean()
    data[f'{stock}_MA21'] = data[close_col].rolling(window=21).mean()

    # Exponential moving average
    data[f'{stock}_EMA21'] = data[close_col].ewm(span=21, adjust=False).mean()

    # Rolling standard deviation (volatility)
    data[f'{stock}_STD21'] = data[close_col].rolling(window=21).std()

    # RSI (Relative Strength Index)
    delta = data[close_col].diff()
    gain = np.where(delta > 0, delta, 0)
    loss = np.where(delta < 0, -delta, 0)
    avg_gain = pd.Series(gain).rolling(window=14).mean()
    avg_loss = pd.Series(loss).rolling(window=14).mean()
    rs = avg_gain / avg_loss
    data[f'{stock}_RSI'] = 100 - (100 / (1 + rs))

# ----------------------------
# Handle missing values from rolling windows
# ----------------------------
data = data.dropna().reset_index(drop=True)
print("✅ Feature engineering complete.")
print("New shape:", data.shape)

# ----------------------------
# Save feature dataset
# ----------------------------
output_path = '../data/processed/stocks_features.csv'
data.to_csv(output_path, index=False)
print(f"📁 Features saved to {output_path}")

# Preview
data.head()
# Out:
# ✅ Data loaded for feature engineering
# Shape: (1481, 21)
# ✅ Feature engineering complete.
# New shape: (1461, 39)
# 📁 Features saved to ../data/processed/stocks_features.csv
#         Date  Close_HDFCBANK.NS  Close_RELIANCE.NS  Close_TCS.NS  \
# 0 2019-01-29         483.142303         538.356567   1682.212524
# 1 2019-01-30         477.765167         531.708435   1681.067139
# 2 2019-01-31         488.390259         545.693909   1708.810547
# 3 2019-02-01         490.855743         555.832520   1722.258179
# 4 2019-02-04         494.248749         574.042419   1739.481201
#
#     Close_^NSEI  High_HDFCBANK.NS  High_RELIANCE.NS  High_TCS.NS  \
# 0  10652.200195        489.106420        547.694960  1687.557637
# 1  10651.799805        483.060114        544.737715  1687.939352
# 2  10830.950195        490.691395        546.827850  1713.604163
# 3  10893.650391        497.089925        558.078198  1726.330655
# 4  10912.250000        496.150722        576.732769  1743.892964
#
# ...

# %%
import pandas as pd
import numpy as np

# =====================================================
# Load your HDFC enhanced file
# =====================================================
file_path = r"C:\JupyterProjects\Stock_ML_Project\Data\Processed\enhanced\hdfcbank_enhanced_model_ready.csv"
df = pd.read_csv(file_path)

# Ensure Date exists and is datetime
if "Date" not in df.columns:
    df["Date"] = pd.date_range(start="2019-01-01", periods=len(df), freq="D")
else:
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# =====================================================
# Load and prepare NIFTY data
# =====================================================
nifty_raw = pd.read_csv(r"C:\JupyterProjects\Stock_ML_Project\Data\raw\stocks_raw.csv")
nifty_raw["Date"] = pd.to_datetime(nifty_raw["Date"], errors="coerce")

nifty = nifty_raw[["Date", "Close_^NSEI"]].rename(columns={"Close_^NSEI": "NIFTY_Close"}).dropna()

# --- Compute NIFTY indicators manually ---
def compute_RSI(series, period=14):
    delta = series.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(period).mean()
    avg_loss = loss.rolling(period).mean()
    rs = avg_gain / avg_loss
    return 100 - (100 / (1 + rs))

nifty["NIFTY_Return"] = nifty["NIFTY_Close"].pct_change()
nifty["NIFTY_MA7"] = nifty["NIFTY_Close"].rolling(window=7).mean()
nifty["NIFTY_MA21"] = nifty["NIFTY_Close"].rolling(window=21).mean()
nifty["NIFTY_RSI"] = compute_RSI(nifty["NIFTY_Close"], 14)
nifty = nifty.ffill().bfill()

# =====================================================
# Merge NIFTY safely (without losing or overwriting any column)
# =====================================================
merged = pd.merge_asof(
    df.sort_values("Date"),
    nifty.sort_values("Date"),
    on="Date",
    direction="nearest",
    tolerance=pd.Timedelta("2D")
)

# Make sure we keep *everything*
merged = merged.copy()
merged = merged.ffill().bfill()

# =====================================================
# Save clean merged output
# =====================================================
save_path = r"C:\JupyterProjects\Stock_ML_Project\Data\Processed\enhanced\hdfcbank_enhanced_model_ready_with_nifty_FINAL_REAL.csv"
merged.to_csv(save_path, index=False)

print(f"✅ Final file saved successfully: {save_path}")
print(f"Columns in final dataset: {list(merged.columns)}")
print("✅ NIFTY features added and all original columns preserved.")
# Out:
# ✅ Final file saved successfully: C:\JupyterProjects\Stock_ML_Project\Data\Processed\enhanced\hdfcbank_enhanced_model_ready_with_nifty_FINAL_REAL.csv
# Columns in final dataset: ['Date', 'HDFCBANK.NS_MA7_x', 'HDFCBANK.NS_MA21_x', 'HDFCBANK.NS_EMA21_x', 'HDFCBANK.NS_STD21_x', 'HDFCBANK.NS_RSI_x', 'Target_Reg_x', 'Target_Cls_x', 'Split_x', 'HDFCBANK.NS_MA7_y', 'HDFCBANK.NS_MA21_y', 'HDFCBANK.NS_EMA21_y', 'HDFCBANK.NS_STD21_y', 'HDFCBANK.NS_RSI_y', 'Target_Reg_y', 'Target_Cls_y', 'Split_y', 'HDFCBANK_Return_3', 'HDFCBANK_Return_5', 'HDFCBANK_Return_10', 'HDFCBANK_Volatility_7', 'HDFCBANK_Volatility_14', 'HDFCBANK_Momentum_5', 'HDFCBANK_Momentum_10', 'HDFCBANK_BB_upper', 'HDFCBANK_BB_lower', 'HDFCBANK_BB_width', 'NIFTY_Close_x', 'NIFTY_Return_x', 'NIFTY_MA7_x', 'NIFTY_MA21_x', 'NIFTY_RSI_x', 'NIFTY_Close_y', 'NIFTY_Return_y', 'NIFTY_MA7_y', 'NIFTY_MA21_y', 'NIFTY_RSI_y']
# ✅ NIFTY features added and all original columns preserved.
