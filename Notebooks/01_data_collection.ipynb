# %%
pip install yfinance pandas
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from yfinance) (4.3.7)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 932.9 kB/s eta 0:00:03
#      ---------- ----------------------------- 0.8/3.0 MB 1.0 MB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 1.2 MB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 1.4 MB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 1.8 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vikhy\miniconda3\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 7.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.0 MB 7.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 8.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 8.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.9 MB/s  0:00:01
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 8.7 MB/s  0:00:00
# Downloading frozendict-2.4.6-py312-none-any.whl (16 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=e0968b7a9a0c3ae79e615bbb3d88181ca3cfa81e5b05283688eb5750d12345ce
#   Stored in directory: c:\users\vikhy\appdata\local\pip\cache\wheels\cc\bd\6f\664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.3-py3-none-any.whl size=139181 sha256=9d2b26c6a03d1714ab0009fe9397934173d4457e1cf20484c5df4089ea696b69
#   Stored in directory: c:\users\vikhy\appdata\local\pip\cache\wheels\e2\48\b6\675a31c56e50b8b343e1ffbb1d9209f0d95025e2cfa0bbeeed
# Successfully built multitasking peewee
# Installing collected packages: pytz, peewee, multitasking, websockets, tzdata, protobuf, frozendict, pandas, curl_cffi, yfinance
#
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [peewee]
#    ------------ ---------------------------  3/10 [websockets]
#    ---------------- -----------------------  4/10 [tzdata]
#    ---------------- -----------------------  4/10 [tzdata]
#    -------------------- -------------------  5/10 [protobuf]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ------------------------------------ ---  9/10 [yfinance]
#    ---------------------------------------- 10/10 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 pandas-2.3.3 peewee-3.18.3 protobuf-6.33.0 pytz-2025.2 tzdata-2025.2 websockets-15.0.1 yfinance-0.2.66
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'multitasking' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'multitasking'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
# ============================
# 📊 PHASE 1: DATA COLLECTION
# ============================

import yfinance as yf
import pandas as pd
from datetime import date

# ----------------------------
# SETTINGS
# ----------------------------
tickers = ['RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', '^NSEI']  # ^NSEI = Nifty50 index
start_date = '2019-01-01'
end_date = '2025-01-01'

# ----------------------------
# DOWNLOAD DATA
# ----------------------------
print(f"Downloading data from {start_date} to {end_date}...")

data = yf.download(tickers, start=start_date, end=end_date, interval='1d', progress=True)

# Flatten multi-level columns (e.g. ('Open', 'RELIANCE.NS') -> 'Open_RELIANCE.NS')
data.columns = ['_'.join(col).strip() for col in data.columns.values]

# Reset index to move 'Date' into a column
data = data.reset_index()

# ----------------------------
# SAVE RAW DATA
# ----------------------------
output_path = '../data/raw/stocks_raw.csv'
data.to_csv(output_path, index=False)
print(f"✅ Data downloaded and saved as {output_path}")

# ----------------------------
# QUICK PREVIEW
# ----------------------------
print("\nPreview of dataset:")
display(data.head())
print("\nShape of data:", data.shape)
print("\nColumns:")
print(data.columns.tolist())
# Out:
# Downloading data from 2019-01-01 to 2025-01-01...
# C:\Users\vikhy\AppData\Local\Temp\ipykernel_41044\4213012542.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date, interval='1d', progress=True)
# [*********************100%***********************]  4 of 4 completed
# ✅ Data downloaded and saved as ../data/raw/stocks_raw.csv
#
# Preview of dataset:
#         Date  Close_HDFCBANK.NS  Close_RELIANCE.NS  Close_TCS.NS  \
# 0 2019-01-01         504.392517         498.490570   1610.928345
# 1 2019-01-02         499.790222         491.998230   1628.283691
# 2 2019-01-03         495.868988         485.928284   1608.515015
# 3 2019-01-04         497.195618         488.551941   1588.958862
# 4 2019-01-07         497.946960         491.264465   1606.779663
#
#     Close_^NSEI  High_HDFCBANK.NS  High_RELIANCE.NS  High_TCS.NS  \
# 0           NaN        505.073439        501.292117  1617.023891
# 1  10792.500000        504.251587        501.158723  1637.723302
# 2  10672.250000        499.731579        495.644616  1646.612426
# 3  10727.349609        499.790265        491.131123  1609.573781
# 4  10771.799805        501.398694        497.356638  1616.007724
#
#      High_^NSEI  Low_HDFCBANK.NS  ...   Low_TCS.NS     Low_^NSEI  \
# 0           NaN       494.413149  ...  1595.858657           NaN
# 1  10895.349609       497.723895  ...  1608.557654  10735.049805
# 2  10814.049805       493.802660  ...  1602.715763  10661.250000
# 3  10741.049805       495.528510  ...  1558.607935  10628.650391
# 4  10835.950195       497.324740  ...  1592.471947  10750.150391
#
#    Open_HDFCBANK.NS  Open_RELIANCE.NS  Open_TCS.NS    Open_^NSEI  \
# 0        499.590634        500.380512  1605.171360           NaN
# 1        503.147997        495.600156  1612.790700  10868.849609
# 2        498.780593        492.487362  1624.642960  10796.799805
# 3        496.679050        487.996102  1608.557891  10699.700195
# 4        499.602373        492.265005  1601.615368  10804.849609
#
#    Volume_HDFCBANK.NS  Volume_RELIANCE.NS  Volume_TCS.NS  Volume_^NSEI
# 0             6373440             9746670        1094883           NaN
# 1             8134232            15628818        2100463      309700.0
# 2            12771664            16288287        2611668      286200.0
# 3             7287120            18516544        4280862      296600.0
# 4             5387012            12060290        1856423      269400.0
#
# [5 rows x 21 columns]
# Shape of data: (1481, 21)
#
# Columns:
# ['Date', 'Close_HDFCBANK.NS', 'Close_RELIANCE.NS', 'Close_TCS.NS', 'Close_^NSEI', 'High_HDFCBANK.NS', 'High_RELIANCE.NS', 'High_TCS.NS', 'High_^NSEI', 'Low_HDFCBANK.NS', 'Low_RELIANCE.NS', 'Low_TCS.NS', 'Low_^NSEI', 'Open_HDFCBANK.NS', 'Open_RELIANCE.NS', 'Open_TCS.NS', 'Open_^NSEI', 'Volume_HDFCBANK.NS', 'Volume_RELIANCE.NS', 'Volume_TCS.NS', 'Volume_^NSEI']
